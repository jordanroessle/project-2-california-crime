# %%
#Import dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from sqlalchemy import create_engine 
import pprint  

# Import API key
api_key = "your api key here"

# %%
url = "https://api.usa.gov/crime/fbi/sapi/"

state_abbrv = "CA"
departments = [] 
department_name = []
county_name = []
state_abbr = [] 
ori = []

# %%
response = json.loads(requests.get(f'{url}api/agencies/byStateAbbr/{state_abbrv}?API_KEY={api_key}').text)

for i in range(len(response["results"])):
        departments.append(response["results"][i])
        department_name.append(response["results"][i]["agency_name"])
        county_name.append(response["results"][i]["county_name"])
        ori.append(response["results"][i]["ori"])
        state_abbr.append(response["results"][i]["state_abbr"])
#print(departments)
print(json.dumps(departments, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "agency_name": "Alameda County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.802,
#         "longitude": -122.26236,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Alameda Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.766888,
#         "longitude": -122.24273,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Albany Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.887703,
#         "longitude": -122.29825,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Berkeley Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.870537,
#         "longitude": -122.27298,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Emeryville Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.648134,
#         "longitude": -121.913291,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Fremont Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.553017,
#         "longitude": -121.97069,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Hayward Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.662106,
#         "longitude": -122.08672,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Livermore Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.674633,
#         "longitude": -121.756935,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Newark Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.536236,
#         "longitude": -122.02951,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Oakland Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.79965,
#         "longitude": -122.27459,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0010900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Piedmont Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.824814,
#         "longitude": -122.23214,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Pleasanton Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.648134,
#         "longitude": -121.913291,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Leandro Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.648134,
#         "longitude": -121.913291,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union City Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.58882,
#         "longitude": -122.02747,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "East Bay Regional Parks: Alameda County",
#         "agency_type_name": "Other",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.71378,
#         "longitude": -122.10035,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "California State University: East Bay",
#         "agency_type_name": "University or College",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.658787,
#         "longitude": -122.062225,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Alameda County",
#         "agency_type_name": "Other",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0011600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Francisco Bay Area Rapid Transit: Alameda County",
#         "agency_type_name": "Other",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.79742,
#         "longitude": -122.26664,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0012100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Dublin Police Department",
#         "agency_type_name": "City",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.799427,
#         "longitude": -122.262505,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA001300X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "University of California: Berkeley",
#         "agency_type_name": "University or College",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.648134,
#         "longitude": -121.913291,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0019700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Alameda County",
#         "agency_type_name": "State Police",
#         "county_name": "ALAMEDA",
#         "division_name": "Pacific",
#         "latitude": 37.606228,
#         "longitude": -122.06034,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0019900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Alpine County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "ALPINE",
#         "division_name": "Pacific",
#         "latitude": 38.61761,
#         "longitude": -119.798999,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0020000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Alpine County",
#         "agency_type_name": "State Police",
#         "county_name": "ALPINE",
#         "division_name": "Pacific",
#         "latitude": 38.85127,
#         "longitude": -120.01934,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0029900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Amador County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 38.352863,
#         "longitude": -120.7679,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0030000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Ione Police Department",
#         "agency_type_name": "City",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 38.44355,
#         "longitude": -120.653856,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0030200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Jackson Police Department",
#         "agency_type_name": "City",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 38.347904,
#         "longitude": -120.77274,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0030300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Sutter Creek Police Department",
#         "agency_type_name": "City",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 38.391117,
#         "longitude": -120.80235,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0030500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Amador County",
#         "agency_type_name": "Other",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0030600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Amador County",
#         "agency_type_name": "State Police",
#         "county_name": "AMADOR",
#         "division_name": "Pacific",
#         "latitude": 38.34309,
#         "longitude": -120.76263,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0039900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Butte County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.665959,
#         "longitude": -121.601919,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Biggs Police Department",
#         "agency_type_name": "City",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.365505,
#         "longitude": -121.69721,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Chico Police Department",
#         "agency_type_name": "City",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.735462,
#         "longitude": -121.81528,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Gridley Police Department",
#         "agency_type_name": "City",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.365505,
#         "longitude": -121.69721,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Oroville Police Department",
#         "agency_type_name": "City",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.508167,
#         "longitude": -121.554825,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Paradise Police Department",
#         "agency_type_name": "City",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.75336,
#         "longitude": -121.62395,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Butte County",
#         "agency_type_name": "Other",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: Northern Buttes",
#         "agency_type_name": "Other State Agency",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.510296,
#         "longitude": -121.50341,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0040700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "California State University: Chico",
#         "agency_type_name": "University or College",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.665959,
#         "longitude": -121.601919,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0049700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Butte County",
#         "agency_type_name": "State Police",
#         "county_name": "BUTTE",
#         "division_name": "Pacific",
#         "latitude": 39.665959,
#         "longitude": -121.601919,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0049900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Calaveras County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "CALAVERAS",
#         "division_name": "Pacific",
#         "latitude": 38.19131,
#         "longitude": -120.66931,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0050000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "City of Angels Police Department",
#         "agency_type_name": "City",
#         "county_name": "CALAVERAS",
#         "division_name": "Pacific",
#         "latitude": 38.184618,
#         "longitude": -120.5594,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0050100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Calaveras County",
#         "agency_type_name": "Other",
#         "county_name": "CALAVERAS",
#         "division_name": "Pacific",
#         "latitude": 38.184618,
#         "longitude": -120.5594,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0050200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: Calaveras County",
#         "agency_type_name": "Other State Agency",
#         "county_name": "CALAVERAS",
#         "division_name": "Pacific",
#         "latitude": 38.184618,
#         "longitude": -120.5594,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0050300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Calaveras County",
#         "agency_type_name": "State Police",
#         "county_name": "CALAVERAS",
#         "division_name": "Pacific",
#         "latitude": 38.189983,
#         "longitude": -120.67146,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0059900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Colusa County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "COLUSA",
#         "division_name": "Pacific",
#         "latitude": 39.205734,
#         "longitude": -122.00377,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0060000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Colusa Police Department",
#         "agency_type_name": "City",
#         "county_name": "COLUSA",
#         "division_name": "Pacific",
#         "latitude": 39.21383,
#         "longitude": -122.009544,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0060100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Williams Police Department",
#         "agency_type_name": "City",
#         "county_name": "COLUSA",
#         "division_name": "Pacific",
#         "latitude": 39.177739,
#         "longitude": -122.237563,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0060200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Colusa County",
#         "agency_type_name": "Other",
#         "county_name": "COLUSA",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0060300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Colusa County",
#         "agency_type_name": "State Police",
#         "county_name": "COLUSA",
#         "division_name": "Pacific",
#         "latitude": 39.177739,
#         "longitude": -122.237563,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0069900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Contra Costa County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.01906,
#         "longitude": -122.13399,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Antioch Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Brentwood Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919037,
#         "longitude": -121.68469,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Clayton Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.94229,
#         "longitude": -121.93776,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Concord Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "El Cerrito Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.916363,
#         "longitude": -122.31207,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Hercules Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.00937,
#         "longitude": -122.26571,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Pinole Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.00441,
#         "longitude": -122.290115,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Pittsburg Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Pleasant Hill Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.96205,
#         "longitude": -122.070656,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0070900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Richmond Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Pablo Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Walnut Creek Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Kensington Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Martinez Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.01375,
#         "longitude": -122.13533,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Lafayette Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.01906,
#         "longitude": -122.13399,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Moraga Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Francisco Bay Area Rapid Transit: Contra Costa County",
#         "agency_type_name": "Other",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.919479,
#         "longitude": -121.951543,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0071800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Contra Costa Community College",
#         "agency_type_name": "University or College",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.01951,
#         "longitude": -122.13532,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0072100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Danville Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.01906,
#         "longitude": -122.13399,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA007230X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Ramon Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA007240X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Orinda Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA007260X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Contra Costa County",
#         "agency_type_name": "Other",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0073300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Oakley Police Department",
#         "agency_type_name": "City",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA007340X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Contra Costa County",
#         "agency_type_name": "State Police",
#         "county_name": "CONTRA COSTA",
#         "division_name": "Pacific",
#         "latitude": 38.00525,
#         "longitude": -122.07482,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0079900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Del Norte County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "DEL NORTE",
#         "division_name": "Pacific",
#         "latitude": 41.75284,
#         "longitude": -124.20048,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0080000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Crescent City Police Department",
#         "agency_type_name": "City",
#         "county_name": "DEL NORTE",
#         "division_name": "Pacific",
#         "latitude": 41.754265,
#         "longitude": -124.20122,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0080100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Del Norte County",
#         "agency_type_name": "State Police",
#         "county_name": "DEL NORTE",
#         "division_name": "Pacific",
#         "latitude": 41.772213,
#         "longitude": -124.185356,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA008980X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "El Dorado County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "EL DORADO",
#         "division_name": "Pacific",
#         "latitude": 38.785532,
#         "longitude": -120.534398,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0090000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Placerville Police Department",
#         "agency_type_name": "City",
#         "county_name": "EL DORADO",
#         "division_name": "Pacific",
#         "latitude": 38.73032,
#         "longitude": -120.79018,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0090100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "South Lake Tahoe Police Department",
#         "agency_type_name": "City",
#         "county_name": "EL DORADO",
#         "division_name": "Pacific",
#         "latitude": 38.933025,
#         "longitude": -119.97075,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0090200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: El Dorado County",
#         "agency_type_name": "Other",
#         "county_name": "EL DORADO",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA009030X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: El Dorado County",
#         "agency_type_name": "State Police",
#         "county_name": "EL DORADO",
#         "division_name": "Pacific",
#         "latitude": 38.785532,
#         "longitude": -120.534398,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0099900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Fresno County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Clovis Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.82397,
#         "longitude": -119.692795,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Coalinga Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.139175,
#         "longitude": -120.362045,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Firebaugh Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Fowler Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.630894,
#         "longitude": -119.67752,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Fresno Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Huron Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Kerman Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.722088,
#         "longitude": -120.06027,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Kingsburg Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Mendota Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.759174,
#         "longitude": -120.373276,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0100900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Orange Cove Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Parlier Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Reedley Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.598927,
#         "longitude": -119.453575,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Sanger Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.70591,
#         "longitude": -119.56111,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Selma Police Department",
#         "agency_type_name": "City",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.567337,
#         "longitude": -119.611984,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "State Center Community College District",
#         "agency_type_name": "University or College",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.739437,
#         "longitude": -119.79724,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0101700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Fresno County",
#         "agency_type_name": "Other",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0102400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: San Joaquin",
#         "agency_type_name": "Other State Agency",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.761006,
#         "longitude": -119.655019,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0103000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Clovis Unified School District",
#         "agency_type_name": "Other",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA010440X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "California State University: Fresno",
#         "agency_type_name": "University or College",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.81583,
#         "longitude": -119.748314,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0109700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Fresno County",
#         "agency_type_name": "State Police",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": 36.757477,
#         "longitude": -119.82758,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0109900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Coalinga State Hospital",
#         "agency_type_name": "Other State Agency",
#         "county_name": "FRESNO",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA010M15M",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Glenn County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "GLENN",
#         "division_name": "Pacific",
#         "latitude": 39.602546,
#         "longitude": -122.4017,
#         "nibrs": false,
# ...
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Santa Paula Police Department",
#         "agency_type_name": "City",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.35691,
#         "longitude": -119.06136,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0560600",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Thousand Oaks Police Department",
#         "agency_type_name": "City",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.26795,
#         "longitude": -119.212875,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0560700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Ventura Police Department",
#         "agency_type_name": "City",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.26,
#         "longitude": -119.2226,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0560800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Simi Valley Police Department",
#         "agency_type_name": "City",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.286324,
#         "longitude": -118.72261,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0560900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: Angeles",
#         "agency_type_name": "Other State Agency",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.358741,
#         "longitude": -119.133143,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0561300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Moorpark Police Department",
#         "agency_type_name": "City",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA056140X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: Channel Coast",
#         "agency_type_name": "Other State Agency",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.358741,
#         "longitude": -119.133143,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0561500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Department of Parks and Recreation: Hungry Valley",
#         "agency_type_name": "Other State Agency",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.358741,
#         "longitude": -119.133143,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0561700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Ventura County",
#         "agency_type_name": "Other",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.358741,
#         "longitude": -119.133143,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0562100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "California State University: Channel Islands",
#         "agency_type_name": "University or College",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.183487,
#         "longitude": -119.04012,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0562200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Ventura County Community College District",
#         "agency_type_name": "University or College",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA056800X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Ventura County",
#         "agency_type_name": "State Police",
#         "county_name": "VENTURA",
#         "division_name": "Pacific",
#         "latitude": 34.261433,
#         "longitude": -119.23135,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0569900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Yolo County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0570000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Davis Police Department",
#         "agency_type_name": "City",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0570100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Winters Police Department",
#         "agency_type_name": "City",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.521507,
#         "longitude": -121.97047,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0570200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Woodland Police Department",
#         "agency_type_name": "City",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0570300",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "West Sacramento Police Department",
#         "agency_type_name": "City",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0570400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Yolo County",
#         "agency_type_name": "Other",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA057050X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "University of California: Davis",
#         "agency_type_name": "University or College",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0579700",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Yolo County",
#         "agency_type_name": "State Police",
#         "county_name": "YOLO",
#         "division_name": "Pacific",
#         "latitude": 38.679595,
#         "longitude": -121.902444,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0579900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Yuba County Sheriff's Office",
#         "agency_type_name": "County",
#         "county_name": "YUBA",
#         "division_name": "Pacific",
#         "latitude": 39.270026,
#         "longitude": -121.34428,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0580000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Marysville Police Department",
#         "agency_type_name": "City",
#         "county_name": "YUBA",
#         "division_name": "Pacific",
#         "latitude": 39.270026,
#         "longitude": -121.34428,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0580100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Wheatland Police Department",
#         "agency_type_name": "City",
#         "county_name": "YUBA",
#         "division_name": "Pacific",
#         "latitude": 39.270026,
#         "longitude": -121.34428,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0580200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Union Pacific Railroad: Yuba County",
#         "agency_type_name": "Other",
#         "county_name": "YUBA",
#         "division_name": "Pacific",
#         "latitude": 37.798763,
#         "longitude": -122.24971,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA058030X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Highway Patrol: Yuba County",
#         "agency_type_name": "State Police",
#         "county_name": "YUBA",
#         "division_name": "Pacific",
#         "latitude": 39.144722,
#         "longitude": -121.64491,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CA0589900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Blue Lake Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADI03900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "La Jolla Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADI0990X",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Tule River Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": 36.228824,
#         "longitude": -118.781061,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0000",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Yurok Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": 41.749903,
#         "longitude": -123.980998,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0200",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Sycuan Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Los Coyotes Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0500",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Hoopa Valley Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": 40.706673,
#         "longitude": -123.925818,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0800",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Coyote Valley Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT0900",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "Table Mountain Rancheria",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT1100",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     },
#     {
#         "agency_name": "San Pasqual Band of Mission Indians Tribal",
#         "agency_type_name": "Tribal",
#         "county_name": "",
#         "division_name": "Pacific",
#         "latitude": null,
#         "longitude": null,
#         "nibrs": false,
#         "nibrs_start_date": null,
#         "ori": "CADIT1400",
#         "region_desc": "Region IV",
#         "region_name": "West",
#         "state_abbr": "CA",
#         "state_name": "California"
#     }
# ]

# %%
#Creating dataframe to pull the ori 
ori_df = pd.DataFrame({"Department_Name": department_name,
                        "State": state_abbr,
                        "County": county_name,
                        "Ori": ori,
                        })
ori_df
# Out:
#                                 Department_Name State   County        Ori
# 0               Alameda County Sheriff's Office    CA  ALAMEDA  CA0010000
# 1                     Alameda Police Department    CA  ALAMEDA  CA0010100
# 2                      Albany Police Department    CA  ALAMEDA  CA0010200
# 3                    Berkeley Police Department    CA  ALAMEDA  CA0010300
# 4                  Emeryville Police Department    CA  ALAMEDA  CA0010400
# ..                                          ...   ...      ...        ...
# 738                          Los Coyotes Tribal    CA           CADIT0500
# 739                         Hoopa Valley Tribal    CA           CADIT0800
# 740                        Coyote Valley Tribal    CA           CADIT0900
# 741                    Table Mountain Rancheria    CA           CADIT1100
# 742  San Pasqual Band of Mission Indians Tribal    CA           CADIT1400
#
# [743 rows x 4 columns]

# %%
crime_data = []

#types of crimes 
assault_a = []
sex_offense = []
man_neg = []
murder = []
rape = []
robbery = []
assault_s = []
ht_c = []
ht_i = []
total = []

for i in range(len(departments)):
    response = json.loads(requests.get(f'{url}api/arrest/agencies/offense/{departments[i]["ori"]}/violent_crime/2019/2019?API_KEY={api_key}').text)
    crime_data.append(response)

print(json.dumps(crime_data[30], indent=4, sort_keys=True))
for i in range(len(crime_data)):
    if len(crime_data[i]["data"]) == 0:
        assault_a.append("N/A")
        sex_offense.append("N/A")
        man_neg.append("N/A")
        murder.append("N/A")
        rape.append("N/A")
        robbery.append("N/A")
        assault_s.append("N/A")
        ht_c.append("N/A")
        ht_i.append("N/A")
        total.append("N/A")
    else:
        assault_a.append(crime_data[i]["data"][0]["value"])
        sex_offense.append(crime_data[i]["data"][1]["value"])
        man_neg.append(crime_data[i]["data"][2]["value"])
        murder.append(crime_data[i]["data"][3]["value"])
        rape.append(crime_data[i]["data"][4]["value"])
        robbery.append(crime_data[i]["data"][5]["value"])
        assault_s.append(crime_data[i]["data"][6]["value"])
        ht_c.append(crime_data[i]["data"][7]["value"])
        ht_i.append(crime_data[i]["data"][8]["value"])
        total.append(assault_a[i] + sex_offense[i] + man_neg[i] + murder[i] + rape[i] + robbery[i] + assault_s[i] + ht_c[i] + ht_i[i])

print(json.dumps(crime_data, indent=4, sort_keys=True))
# Out:
# {
#     "category": "Arrestee Offense",
#     "data": [
#         {
#             "data_year": 2019,
#             "key": "Aggravated Assault",
#             "month_num": 0,
#             "value": 1
#         },
#         {
#             "data_year": 2019,
#             "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Manslaughter by Negligence",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Murder and Nonnegligent Manslaughter",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Rape",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Robbery",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Simple Assault",
#             "month_num": 0,
#             "value": 5
#         },
#         {
#             "data_year": 2019,
#             "key": "Human Trafficking - Commercial Sex Acts",
#             "month_num": 0,
#             "value": 0
#         },
#         {
#             "data_year": 2019,
#             "key": "Human Trafficking - Involuntary Servitude",
#             "month_num": 0,
#             "value": 0
#         }
#     ],
#     "keys": [
#         "Aggravated Assault",
#         "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#         "Manslaughter by Negligence",
#         "Murder and Nonnegligent Manslaughter",
#         "Rape",
#         "Robbery",
#         "Simple Assault",
#         "Human Trafficking - Commercial Sex Acts",
#         "Human Trafficking - Involuntary Servitude"
#     ],
#     "noun": "Offense",
#     "precise_data": [],
#     "short_title": "offense",
#     "title": "Arrests for Crime Against Person Offenses",
#     "ui_restriction": null,
#     "ui_type": "basic_table"
# }
# [
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 353
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 20
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 7
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 71
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 384
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 90
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 12
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 18
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 197
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 18
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 26
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 194
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 28
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 6
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 99
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 211
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 38
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 22
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 75
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 160
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 27
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 6
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 87
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 179
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 247
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 36
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 31
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 307
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 147
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 14
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 10
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 208
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 44
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 11
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 81
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 934
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 68
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 37
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 28
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 347
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 1871
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 6
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 46
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 9
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 20
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 86
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 161
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 19
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 87
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 163
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 122
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 8
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 39
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 93
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 16
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 5
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 17
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 46
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 19
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 55
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 214
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 79
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 7
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 19
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 79
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 9
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 7
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 47
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 30
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
# ...
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 3
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 4
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 2
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 17
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 1
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 10
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [
#             {
#                 "data_year": 2019,
#                 "key": "Aggravated Assault",
#                 "month_num": 0,
#                 "value": 6
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Manslaughter by Negligence",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Murder and Nonnegligent Manslaughter",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Rape",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Robbery",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Simple Assault",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Commercial Sex Acts",
#                 "month_num": 0,
#                 "value": 0
#             },
#             {
#                 "data_year": 2019,
#                 "key": "Human Trafficking - Involuntary Servitude",
#                 "month_num": 0,
#                 "value": 0
#             }
#         ],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     },
#     {
#         "category": "Arrestee Offense",
#         "data": [],
#         "keys": [
#             "Aggravated Assault",
#             "Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)",
#             "Manslaughter by Negligence",
#             "Murder and Nonnegligent Manslaughter",
#             "Rape",
#             "Robbery",
#             "Simple Assault",
#             "Human Trafficking - Commercial Sex Acts",
#             "Human Trafficking - Involuntary Servitude"
#         ],
#         "noun": "Offense",
#         "precise_data": [],
#         "short_title": "offense",
#         "title": "Arrests for Crime Against Person Offenses",
#         "ui_restriction": null,
#         "ui_type": "basic_table"
#     }
# ]

# %%
crimes_df = pd.DataFrame({"Ori": ori,
                           "Agg_Assult": assault_a,
                           "Sex_Offences":sex_offense,
                           "Manslaughter_Neg": man_neg, 
                           "Murder_and_Nonneg_Man": murder,  
                           "Rape": rape,  
                           "Robbery": robbery, 
                           "Simp_Assult": assault_s,  
                           "Humman_Trafficking_Commercial_SA": ht_c, 
                           "Humman_Trafficking_Invol_Ser": ht_i,
                           "Offences_Total": total
                          })
crimes_df
# Out:
#            Ori Agg_Assult Sex_Offences Manslaughter_Neg Murder_and_Nonneg_Man  \
# 0    CA0010000        353           20                1                     4
# 1    CA0010100         90           12                0                     0
# 2    CA0010200         18            3                0                     0
# 3    CA0010300        194           28                0                     2
# 4    CA0010400         38            3                0                     0
# ..         ...        ...          ...              ...                   ...
# 738  CADIT0500        N/A          N/A              N/A                   N/A
# 739  CADIT0800          6            0                0                     0
# 740  CADIT0900        N/A          N/A              N/A                   N/A
# 741  CADIT1100        N/A          N/A              N/A                   N/A
# 742  CADIT1400        N/A          N/A              N/A                   N/A
#
#     Rape Robbery Simp_Assult Humman_Trafficking_Commercial_SA  \
# 0      7      71         384                                0
# 1      1      18         197                                0
# 2      3       4          26                                0
# 3      6      99         211                                0
# 4      4      22          75                                0
# ..   ...     ...         ...                              ...
# 738  N/A     N/A         N/A                              N/A
# 739    0       0           0                                0
# 740  N/A     N/A         N/A                              N/A
# 741  N/A     N/A         N/A                              N/A
# 742  N/A     N/A         N/A                              N/A
#
#     Humman_Trafficking_Invol_Ser Offences_Total
# 0                              0            840
# 1                              0            318
# 2                              0             54
# 3                              0            540
# 4                              0            142
# ..                           ...            ...
# 738                          N/A            N/A
# 739                            0              6
# 740                          N/A            N/A
# 741                          N/A            N/A
# 742                          N/A            N/A
#
# [743 rows x 11 columns]

# %%
ca_crimes_df = pd.merge(ori_df, crimes_df, how='right', on='Ori')
ca_crimes_df
# Out:
#                                 Department_Name State   County        Ori  \
# 0               Alameda County Sheriff's Office    CA  ALAMEDA  CA0010000
# 1                     Alameda Police Department    CA  ALAMEDA  CA0010100
# 2                      Albany Police Department    CA  ALAMEDA  CA0010200
# 3                    Berkeley Police Department    CA  ALAMEDA  CA0010300
# 4                  Emeryville Police Department    CA  ALAMEDA  CA0010400
# ..                                          ...   ...      ...        ...
# 738                          Los Coyotes Tribal    CA           CADIT0500
# 739                         Hoopa Valley Tribal    CA           CADIT0800
# 740                        Coyote Valley Tribal    CA           CADIT0900
# 741                    Table Mountain Rancheria    CA           CADIT1100
# 742  San Pasqual Band of Mission Indians Tribal    CA           CADIT1400
#
#     Agg_Assult Sex_Offences Manslaughter_Neg Murder_and_Nonneg_Man Rape  \
# 0          353           20                1                     4    7
# 1           90           12                0                     0    1
# 2           18            3                0                     0    3
# 3          194           28                0                     2    6
# 4           38            3                0                     0    4
# ..         ...          ...              ...                   ...  ...
# 738        N/A          N/A              N/A                   N/A  N/A
# 739          6            0                0                     0    0
# 740        N/A          N/A              N/A                   N/A  N/A
# 741        N/A          N/A              N/A                   N/A  N/A
# 742        N/A          N/A              N/A                   N/A  N/A
#
#     Robbery Simp_Assult Humman_Trafficking_Commercial_SA  \
# 0        71         384                                0
# 1        18         197                                0
# 2         4          26                                0
# 3        99         211                                0
# 4        22          75                                0
# ..      ...         ...                              ...
# 738     N/A         N/A                              N/A
# 739       0           0                                0
# 740     N/A         N/A                              N/A
# 741     N/A         N/A                              N/A
# 742     N/A         N/A                              N/A
#
#     Humman_Trafficking_Invol_Ser Offences_Total
# 0                              0            840
# 1                              0            318
# 2                              0             54
# 3                              0            540
# 4                              0            142
# ..                           ...            ...
# 738                          N/A            N/A
# 739                            0              6
# 740                          N/A            N/A
# 741                          N/A            N/A
# 742                          N/A            N/A
#
# [743 rows x 14 columns]

# %%
ca_crimes_df.to_csv('CA_Crime.csv')

# %%
cities = []

for i,pd in enumerate(ca_crimes_df['Department_Name']):
    if 'Police Department' in pd:
        cities.append(pd.split(' Police')[0])
    else:
        ca_crimes_df= ca_crimes_df.drop(i)
ca_crimes_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-302ad68e9c4c> in <module>
#       5         cities.append(pd.split(' Police')[0])
#       6     else:
# ----> 7         ca_crimes_df= ca_crimes_df.drop(i)
#       8 ca_crimes_df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: '[10] not found in axis'
